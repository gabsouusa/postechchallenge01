# %%
import requests
from bs4 import BeautifulSoup
import re
import pandas as pd

# %%
def capturar_anos(opcao):
    url = f'http://vitibrasil.cnpuv.embrapa.br/index.php?ano=2023&opcao={opcao}'
    try:
        response = requests.get(url)
        response.raise_for_status()
        soup = BeautifulSoup(response.text, 'html.parser')

        label_ano = soup.find('label', class_='lbl_pesq')
        if label_ano:
            texto = label_ano.get_text(strip=True) 
            print(f"🔎 Texto do label encontrado: {texto}")  

            anos = re.findall(r'\[(\d{4})-(\d{4})\]', texto)
            if anos:
                ano_inicio, ano_fim = map(int, anos[0])
                print(f"📅 Intervalo de anos detectado: {ano_inicio} - {ano_fim}")
                return ano_inicio, ano_fim
            else:
                print("⚠️ Regex não encontrou o intervalo de anos.")
                return None, None
        else:
            print("❌ Elemento <label class='lbl_pesq'> não encontrado.")
            return None, None

    except requests.exceptions.RequestException as e:
        print(f"Erro ao acessar {url}: {e}")
        return None, None

# %%
teste, teste1 = map(int, capturar_anos('opt_02'))
print(teste, teste1)
# Out:
# 🔎 Texto do label encontrado: Ano: [1970-2023]
# 📅 Intervalo de anos detectado: 1970 - 2023
# 1970 2023

# %%
def capturar_subopcoes(opcao):
    """
    Descobre dinamicamente os subopções (ex: subopt_01) e seus nomes amigáveis para uma dada opção.
    """
    url = f'http://vitibrasil.cnpuv.embrapa.br/index.php?ano=2023&opcao={opcao}'
    subopcoes = {}

    try:
        response = requests.get(url)
        response.raise_for_status()
        soup = BeautifulSoup(response.text, 'html.parser')


        botoes = soup.find_all('button', {'name': 'subopcao'})
        for botao in botoes:
            valor = botao.get('value')
            nome = botao.get_text(strip=True)
            if valor and nome:
                subopcoes[valor] = nome

    except requests.exceptions.RequestException as e:
        print(f"Erro ao acessar subopções de {opcao}: {e}")

    return subopcoes

# %%
teste = capturar_subopcoes('opt_05')
print(teste)
# Out:
# {'subopt_01': 'Vinhos de mesa', 'subopt_02': 'Espumantes', 'subopt_03': 'Uvas frescas', 'subopt_04': 'Uvas passas', 'subopt_05': 'Suco de uva'}

# %%
def capturar_dados_opt_02_04(ano_inicio, ano_fim):
    """
    Coleta e interpreta os dados da tabela HTML da opção opt_02 e opt_04 do site da Embrapa.,
    estruturando produtos e subprodutos com seus respectivos valores.
    """
    dados = []

    for ano in range(ano_inicio, ano_fim + 1):
        print(f"\n📥 Coletando dados para o ano {ano}, opção opt_02...")
        url = f'http://vitibrasil.cnpuv.embrapa.br/index.php?ano={ano}&opcao=opt_02'

        try:
            response = requests.get(url)
            response.raise_for_status()
            soup = BeautifulSoup(response.text, 'html.parser')

            tabela = soup.find('table', class_='tb_base tb_dados')
            if not tabela:
                print(f"⚠️ Nenhuma tabela válida encontrada para o ano {ano}.")
                continue

            produto_atual = None

            for row in tabela.find_all('tr'):
                cols = row.find_all('td')

                if not cols or len(cols) < 2:
                    continue

                primeira_coluna = cols[0].get_text(strip=True)
                segunda_coluna = cols[1].get_text(strip=True)


                if not primeira_coluna or 'total' in primeira_coluna.lower():
                    continue

                if segunda_coluna == '-' or segunda_coluna.strip() == '':
                    valor = None
                else:
                    try:
                        valor = float(segunda_coluna.replace('.', '').replace(',', '.'))
                    except ValueError:
                        valor = None


                if 'tb_item' in cols[0].get('class', []):
                    produto_atual = primeira_coluna
                    dados.append({
                        'ano': ano,
                        'produto': produto_atual,
                        'subproduto': 'Valor Total Produto',
                        'quantidade_l': valor
                    })

                elif 'tb_subitem' in cols[0].get('class', []) and produto_atual:
                    subproduto = primeira_coluna.lower()
                    dados.append({
                        'ano': ano,
                        'produto': produto_atual,
                        'subproduto': subproduto,
                        'quantidade_l': valor
                    })

        except requests.exceptions.RequestException as e:
            print(f"Erro ao acessar {url}: {e}")
            continue

    return pd.DataFrame(dados)

# %%
def capturar_dados_opt_03(ano_inicio, ano_fim):
    """
    Coleta os dados de todas as subopções da opção opt_03,
    estruturando cultivar, subproduto e tipo de comercialização com respectivos valores.
    """
    dados = []
    subopcoes = capturar_subopcoes('opt_03')

    for ano in range(ano_inicio, ano_fim + 1):
        for sub, tipo_nome in subopcoes.items():
            print(f"\n📥 Coletando dados para ano {ano}, subopção {sub} ({tipo_nome})...")
            url = f'http://vitibrasil.cnpuv.embrapa.br/index.php?ano={ano}&opcao=opt_03&subopcao={sub}'

            try:
                response = requests.get(url)
                response.raise_for_status()
                soup = BeautifulSoup(response.text, 'html.parser')

                tabela = soup.find('table', class_='tb_base tb_dados')
                if not tabela:
                    print(f"⚠️ Nenhuma tabela válida encontrada para o ano {ano}, {sub}.")
                    continue

                cultivar_atual = None

                for row in tabela.find_all('tr'):
                    cols = row.find_all('td')

                    if not cols or len(cols) < 2:
                        continue

                    primeira_coluna = cols[0].get_text(strip=True)
                    segunda_coluna = cols[1].get_text(strip=True)

                    if not primeira_coluna or 'total' in primeira_coluna.lower():
                        continue

                    if segunda_coluna == '-' or segunda_coluna.strip() == '':
                        valor = None
                    else:
                        try:
                            valor = float(segunda_coluna.replace('.', '').replace(',', '.'))
                        except ValueError:
                            valor = None

                    if 'tb_item' in cols[0].get('class', []):
                        cultivar_atual = primeira_coluna
                        dados.append({
                            'ano': ano,
                            'tipo': tipo_nome,
                            'cultivar': cultivar_atual,
                            'subproduto': 'valor total cultivar',
                            'quantidade_kg': valor
                        })

                    elif 'tb_subitem' in cols[0].get('class', []) and cultivar_atual:
                        subproduto = primeira_coluna.lower()
                        dados.append({
                            'ano': ano,
                            'tipo': tipo_nome,
                            'cultivar': cultivar_atual,
                            'subproduto': subproduto,
                            'quantidade_kg': valor
                        })

            except requests.exceptions.RequestException as e:
                print(f"Erro ao acessar {url}: {e}")
                continue

    return pd.DataFrame(dados)

# %%
def capturar_dados_opt_05_06(opcao, ano_inicio, ano_fim):
    """
    Raspagem automatizada para opt_05 e opt_06, com subopções e estrutura de exportação (país, quantidade, valor).
    Inclui logs para ajudar a depurar problemas com dados NaN.
    """
    dados = []
    subopcoes = capturar_subopcoes(opcao)

    for ano in range(ano_inicio, ano_fim + 1):
        for sub, tipo_nome in subopcoes.items():
            print(f"\n📥 Coletando dados para {opcao} - {tipo_nome} ({sub}) - Ano {ano}")
            url = f'http://vitibrasil.cnpuv.embrapa.br/index.php?ano={ano}&opcao={opcao}&subopcao={sub}'

            try:
                response = requests.get(url)
                response.raise_for_status()
                soup = BeautifulSoup(response.text, 'html.parser')

                tabela = soup.find('table', class_='tb_base tb_dados')
                if not tabela:
                    print(f"⚠️ Tabela não encontrada para {ano}, {opcao}, {sub}")
                    continue

                for row in tabela.find_all('tr'):
                    cols = row.find_all('td')

                    if len(cols) != 3:
                        print(f"❌ Ignorando linha com {len(cols)} colunas: {[col.get_text(strip=True) for col in cols]}")
                        continue

                    pais = cols[0].get_text(strip=True)
                    quantidade_raw = cols[1].get_text(strip=True)
                    valor_raw = cols[2].get_text(strip=True)

                    print(f"➡️ País: {pais}, Quantidade (bruto): '{quantidade_raw}', Valor (bruto): '{valor_raw}'")

                    try:
                        quantidade = float(quantidade_raw.replace('.', '').replace(',', '.')) \
                            if quantidade_raw and quantidade_raw != '-' else None
                    except ValueError:
                        print(f"⚠️ Erro ao converter quantidade: {quantidade_raw}")
                        quantidade = None

                    try:
                        valor = float(valor_raw.replace('.', '').replace(',', '.')) \
                            if valor_raw and valor_raw != '-' else None
                    except ValueError:
                        print(f"⚠️ Erro ao converter valor: {valor_raw}")
                        valor = None

                    dados.append({
                        'ano': ano,
                        'tipo': tipo_nome,
                        'pais': pais,
                        'quantidade_kg': quantidade,
                        'valor_usd': valor
                    })

            except requests.exceptions.RequestException as e:
                print(f"Erro ao acessar {url}: {e}")
                continue

    return pd.DataFrame(dados)

# %%
def capturar_dados_opt_02(ano_inicio, ano_fim):
    return capturar_dados_opt_02_04(ano_inicio, ano_fim)

def capturar_dados_opt_04(ano_inicio, ano_fim):
    return capturar_dados_opt_02_04(ano_inicio, ano_fim)

def capturar_dados_opt_05(ano_inicio, ano_fim):
    return capturar_dados_opt_05_06('opt_05', ano_inicio, ano_fim)

def capturar_dados_opt_06(ano_inicio, ano_fim):
    return capturar_dados_opt_05_06('opt_06', ano_inicio, ano_fim)

# %%
def capturar_dados(opcao, ano_inicio, ano_fim):
    if opcao == 'opt_02':
        return capturar_dados_opt_02(ano_inicio, ano_fim)
    elif opcao == 'opt_03': 
        return capturar_dados_opt_03(ano_inicio, ano_fim)
    elif opcao == 'opt_04':
        return capturar_dados_opt_04(ano_inicio, ano_fim)
    elif opcao == 'opt_05':
        return capturar_dados_opt_05(ano_inicio, ano_fim)
    elif opcao == 'opt_06':
        return capturar_dados_opt_06(ano_inicio, ano_fim)
    else:
        print(f"⚠️ Nenhum parser implementado para a opção {opcao}")
        return pd.DataFrame()

# %%
def main():
    opcoes = [
        'opt_02',
        'opt_03',
        'opt_04',
        'opt_05',
        'opt_06'
        ]
    dados_opcoes = {}

    for idx, opcao in enumerate(opcoes, start=1):
        print(f'\n🚀 Processando opção {idx}/{len(opcoes)}: {opcao}')
        ano_inicio, ano_fim = capturar_anos(opcao)

        if ano_inicio and ano_fim:
            df = capturar_dados(opcao, ano_inicio, ano_fim)
            if not df.empty:
                dados_opcoes[opcao] = df
                print(f"✅ Dados coletados para {opcao}. {len(df)} registros.")
            else:
                print(f"⚠️ Nenhum dado encontrado para {opcao}.")
        else:
            print(f"❌ Intervalo de anos não encontrado para {opcao}.")

    for opcao, df in dados_opcoes.items():
        print(f"\n🔎 Amostra dos dados da opção {opcao}:")
        print(df.head())

# %%
df = capturar_dados('opt_06', 2020, 2023)
df = pd.DataFrame(df)
# Out:
# 📥 Coletando dados para opt_06 - Vinhos de mesa (subopt_01) - Ano 2020
# ❌ Ignorando linha com 0 colunas: []
# ➡️ País: Afeganistão, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: África do Sul, Quantidade (bruto): '4', Valor (bruto): '21'
# ➡️ País: Alemanha, República Democrática, Quantidade (bruto): '6.261', Valor (bruto): '32.605'
# ➡️ País: Angola, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Anguilla, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Antígua e Barbuda, Quantidade (bruto): '624', Valor (bruto): '1.864'
# ➡️ País: Antilhas Holandesas, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Arábia Saudita, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Argélia, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Argentina, Quantidade (bruto): '1.015', Valor (bruto): '4.176'
# ➡️ País: Aruba, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Austrália, Quantidade (bruto): '1.013', Valor (bruto): '3.413'
# ➡️ País: Áustria, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Bahamas, Quantidade (bruto): '1.212', Valor (bruto): '3.703'
# ➡️ País: Bangladesh, Quantidade (bruto): '3', Valor (bruto): '29'
# ➡️ País: Barbados, Quantidade (bruto): '143', Valor (bruto): '169'
# ➡️ País: Barein, Quantidade (bruto): '8', Valor (bruto): '28'
# ➡️ País: Bélgica, Quantidade (bruto): '3.166', Valor (bruto): '20.460'
# ➡️ País: Belice, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Benin, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Bermudas, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Bolívia, Quantidade (bruto): '9.900', Valor (bruto): '16.025'
# ➡️ País: Bósnia-Herzegovina, Quantidade (bruto): '45', Valor (bruto): '52'
# ➡️ País: Brasil, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Bulgária, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Cabo Verde, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Camarões, Quantidade (bruto): '0', Valor (bruto): '178'
# ➡️ País: Canadá, Quantidade (bruto): '1.672', Valor (bruto): '8.431'
# ➡️ País: Catar, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Cayman, Ilhas, Quantidade (bruto): '123', Valor (bruto): '339'
# ➡️ País: Chile, Quantidade (bruto): '11', Valor (bruto): '13'
# ➡️ País: China, Quantidade (bruto): '122.253', Valor (bruto): '363.000'
# ➡️ País: Chipre, Quantidade (bruto): '2.478', Valor (bruto): '6.785'
# ➡️ País: Cingapura, Quantidade (bruto): '4.049', Valor (bruto): '9.316'
# ➡️ País: Cocos (Keeling), Ilhas, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Colômbia, Quantidade (bruto): '15.660', Valor (bruto): '23.780'
# ➡️ País: Comores, Quantidade (bruto): '9', Valor (bruto): '25'
# ➡️ País: Congo, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Coreia, Republica Sul, Quantidade (bruto): '103', Valor (bruto): '433'
# ➡️ País: Costa do Marfim, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Costa Rica, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Coveite (Kuweit), Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Croácia, Quantidade (bruto): '21', Valor (bruto): '123'
# ➡️ País: Cuba, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Curaçao, Quantidade (bruto): '47.962', Valor (bruto): '65.986'
# ➡️ País: Dinamarca, Quantidade (bruto): '659', Valor (bruto): '1.962'
# ➡️ País: Dominica, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: El Salvador, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Emirados Arabes Unidos, Quantidade (bruto): '581', Valor (bruto): '2.279'
# ➡️ País: Equador, Quantidade (bruto): '3.780', Valor (bruto): '3.824'
# ➡️ País: Eslovaca, Republica, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Espanha, Quantidade (bruto): '28', Valor (bruto): '126'
# ➡️ País: Estados Unidos, Quantidade (bruto): '300.178', Valor (bruto): '610.793'
# ➡️ País: Estônia, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Filipinas, Quantidade (bruto): '719', Valor (bruto): '1.548'
# ➡️ País: Finlândia, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: França, Quantidade (bruto): '12.622', Valor (bruto): '57.144'
# ➡️ País: Gabão, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Gana, Quantidade (bruto): '18.810', Valor (bruto): '22.027'
# ➡️ País: Gibraltar, Quantidade (bruto): '769', Valor (bruto): '2.860'
# ➡️ País: Granada, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Grécia, Quantidade (bruto): '6.859', Valor (bruto): '18.092'
# ➡️ País: Guatemala, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Guiana, Quantidade (bruto): '990', Valor (bruto): '2.577'
# ➡️ País: Guiana Francesa, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Guine Bissau, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Guine Equatorial, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Haiti, Quantidade (bruto): '399.128', Valor (bruto): '471.152'
# ➡️ País: Honduras, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Hong Kong, Quantidade (bruto): '15.159', Valor (bruto): '41.987'
# ➡️ País: Hungria, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Ilha de Man, Quantidade (bruto): '11', Valor (bruto): '121'
# ➡️ País: Ilhas Virgens, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Índia, Quantidade (bruto): '7', Valor (bruto): '10'
# ➡️ País: Indonésia, Quantidade (bruto): '5', Valor (bruto): '6'
# ➡️ País: Irã, Quantidade (bruto): '21', Valor (bruto): '35'
# ➡️ País: Iraque, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Irlanda, Quantidade (bruto): '29', Valor (bruto): '257'
# ➡️ País: Itália, Quantidade (bruto): '91', Valor (bruto): '376'
# ➡️ País: Jamaica, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Japão, Quantidade (bruto): '36.442', Valor (bruto): '92.674'
# ➡️ País: Jordânia, Quantidade (bruto): '12', Valor (bruto): '52'
# ➡️ País: Letônia, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Líbano, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Libéria, Quantidade (bruto): '5.155', Valor (bruto): '17.624'
# ➡️ País: Luxemburgo, Quantidade (bruto): '1.086', Valor (bruto): '5.110'
# ➡️ País: Macau, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Malásia, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Malavi, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Malta, Quantidade (bruto): '3.490', Valor (bruto): '9.688'
# ➡️ País: Marshall, Ilhas, Quantidade (bruto): '6.270', Valor (bruto): '19.639'
# ➡️ País: Martinica, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Mauritânia, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: México, Quantidade (bruto): '24', Valor (bruto): '226'
# ➡️ País: Moçambique, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Montenegro, Quantidade (bruto): '9', Valor (bruto): '20'
# ➡️ País: Namíbia, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Nicarágua, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Nigéria, Quantidade (bruto): '12.094', Valor (bruto): '26.514'
# ➡️ País: Noruega, Quantidade (bruto): '1.859', Valor (bruto): '15.134'
# ➡️ País: Nova Caledônia, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Nova Zelândia, Quantidade (bruto): '95', Valor (bruto): '515'
# ➡️ País: Omã, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Países Baixos, Quantidade (bruto): '248', Valor (bruto): '1.532'
# ➡️ País: Palau, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Panamá, Quantidade (bruto): '10.821', Valor (bruto): '28.372'
# ➡️ País: Paraguai, Quantidade (bruto): '3.299.013', Valor (bruto): '3.869.243'
# ➡️ País: Peru, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Pitcairn, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Polônia, Quantidade (bruto): '74', Valor (bruto): '86'
# ➡️ País: Porto Rico, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Portugal, Quantidade (bruto): '7.958', Valor (bruto): '34.518'
# ➡️ País: Quênia, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Reino Unido, Quantidade (bruto): '22.913', Valor (bruto): '82.722'
# ➡️ País: República Dominicana, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Rússia, Quantidade (bruto): '1.463', Valor (bruto): '8.550'
# ➡️ País: São Cristóvão e Névis, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: São Tomé e Príncipe, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: São Vicente e Granadinas, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Senegal, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Serra Leoa, Quantidade (bruto): '9.240', Valor (bruto): '13.050'
# ➡️ País: Sérvia, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Singapura, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Suazilândia, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Suécia, Quantidade (bruto): '6', Valor (bruto): '24'
# ➡️ País: Suíça, Quantidade (bruto): '2.827', Valor (bruto): '27.930'
# ➡️ País: Suriname, Quantidade (bruto): '4.185', Valor (bruto): '5.277'
# ➡️ País: Tailândia, Quantidade (bruto): '534', Valor (bruto): '1.753'
# ➡️ País: Taiwan (Formosa), Quantidade (bruto): '963', Valor (bruto): '4.673'
# ➡️ País: Tanzânia, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Tcheca, República, Quantidade (bruto): '563', Valor (bruto): '4.805'
# ➡️ País: Togo, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Toquelau, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Trinidade Tobago, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Tunísia, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Turquia, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Tuvalu, Quantidade (bruto): '2', Valor (bruto): '4'
# ➡️ País: Uruguai, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Vanuatu, Quantidade (bruto): '18', Valor (bruto): '31'
# ➡️ País: Venezuela, Quantidade (bruto): '4.086', Valor (bruto): '9.808'
# ➡️ País: Vietnã, Quantidade (bruto): '86', Valor (bruto): '584'
# ➡️ País: Total, Quantidade (bruto): '4.409.717', Valor (bruto): '6.078.288'
#
# 📥 Coletando dados para opt_06 - Espumantes (subopt_02) - Ano 2020
# ❌ Ignorando linha com 0 colunas: []
# ➡️ País: África do Sul, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Alemanha, Quantidade (bruto): '2.388', Valor (bruto): '14.767'
# ➡️ País: Angola, Quantidade (bruto): '24', Valor (bruto): '38'
# ➡️ País: Antigua e Barbuda, Quantidade (bruto): '32', Valor (bruto): '328'
# ➡️ País: Antilhas Holandesas, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Argentina, Quantidade (bruto): '315', Valor (bruto): '894'
# ➡️ País: Aruba, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Australia, Quantidade (bruto): '144', Valor (bruto): '503'
# ➡️ País: Bahamas, Quantidade (bruto): '434', Valor (bruto): '1.033'
# ➡️ País: Bangladesh, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Barbados, Quantidade (bruto): '57', Valor (bruto): '105'
# ➡️ País: Belgica, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Benin, Quantidade (bruto): '24', Valor (bruto): '181'
# ➡️ País: Bermudas, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Bolívia, Quantidade (bruto): '5.994', Valor (bruto): '16.901'
# ➡️ País: Bósnia-Herzegovina, Quantidade (bruto): '168', Valor (bruto): '161'
# ➡️ País: Bulgaria, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Cabo Verde, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Camarões, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Canada, Quantidade (bruto): '413', Valor (bruto): '3.063'
# ➡️ País: Catar, Quantidade (bruto): '78', Valor (bruto): '6.651'
# ➡️ País: Cayman, Ilhas, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Chile, Quantidade (bruto): '90', Valor (bruto): '346'
# ➡️ País: China, Quantidade (bruto): '29.921', Valor (bruto): '103.986'
# ➡️ País: Chipre, Quantidade (bruto): '307', Valor (bruto): '1.019'
# ➡️ País: Cingapura, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Colombia, Quantidade (bruto): '24.578', Valor (bruto): '74.854'
# ➡️ País: Coreia do Sul, Republica da, Quantidade (bruto): '24', Valor (bruto): '53'
# ➡️ País: Costa Rica, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Cuba, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Curaçao, Quantidade (bruto): '2.186', Valor (bruto): '8.451'
# ➡️ País: Dinamarca, Quantidade (bruto): '452', Valor (bruto): '1.798'
# ➡️ País: Djibuti, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Dominica, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: El Salvador, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Emirados Arabes Unidos, Quantidade (bruto): '9', Valor (bruto): '36'
# ➡️ País: Equador, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Espanha, Quantidade (bruto): '29', Valor (bruto): '230'
# ➡️ País: Estados Unidos, Quantidade (bruto): '634.243', Valor (bruto): '1.647.310'
# ➡️ País: Estonia, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Falkland (Malvinas), Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Filipinas, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Filânldia, Quantidade (bruto): '1.078', Valor (bruto): '7.065'
# ➡️ País: França, Quantidade (bruto): '7.481', Valor (bruto): '37.286'
# ➡️ País: Gana, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Gibraltar, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Granada, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Grécia, Quantidade (bruto): '97', Valor (bruto): '309'
# ➡️ País: Guatemala, Quantidade (bruto): '760', Valor (bruto): '4.318'
# ➡️ País: Guiana, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Guiné Equatorial, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Guiné-Bissau, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Haiti, Quantidade (bruto): '1.331', Valor (bruto): '2.737'
# ➡️ País: Honduras, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Hong Kong, Quantidade (bruto): '4.124', Valor (bruto): '11.770'
# ➡️ País: Hungria, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Ilha de Man, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Índia, Quantidade (bruto): '25', Valor (bruto): '80'
# ➡️ País: Iraque, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Irlanda, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Islândia, Quantidade (bruto): '10', Valor (bruto): '45'
# ➡️ País: Itália, Quantidade (bruto): '150', Valor (bruto): '253'
# ➡️ País: Japão, Quantidade (bruto): '7.294', Valor (bruto): '28.930'
# ➡️ País: Jordânia, Quantidade (bruto): '30', Valor (bruto): '103'
# ➡️ País: Letônia, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Líbano, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Libéria, Quantidade (bruto): '1.105', Valor (bruto): '6.684'
# ➡️ País: Luxemburgo, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Maldivas, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Malta, Quantidade (bruto): '1.692', Valor (bruto): '2.862'
# ➡️ País: Marrocos, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Marshall, Ilhas, Quantidade (bruto): '2.093', Valor (bruto): '4.587'
# ➡️ País: Montenegro, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: México, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Nicarágua, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Nigéria, Quantidade (bruto): '4.613', Valor (bruto): '15.728'
# ➡️ País: Noruega, Quantidade (bruto): '172', Valor (bruto): '321'
# ➡️ País: Nova Zelândia, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Países Baixos (Holanda), Quantidade (bruto): '38', Valor (bruto): '717'
# ➡️ País: Panamá, Quantidade (bruto): '7.163', Valor (bruto): '15.019'
# ➡️ País: Paraguai, Quantidade (bruto): '16.231', Valor (bruto): '48.614'
# ➡️ País: Peru, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Polônia, Quantidade (bruto): '14', Valor (bruto): '19'
# ➡️ País: Porto Rico, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Portugal, Quantidade (bruto): '631', Valor (bruto): '11.065'
# ➡️ País: Quênia, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Reino Unido, Quantidade (bruto): '8.084', Valor (bruto): '42.414'
# ➡️ País: Republica Dominicana, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Republica Tcheca, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Rússia, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Serra Leoa, Quantidade (bruto): '450', Valor (bruto): '2.140'
# ➡️ País: Sérvia, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Singapura, Quantidade (bruto): '979', Valor (bruto): '2.193'
# ➡️ País: Suécia, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Suíça, Quantidade (bruto): '672', Valor (bruto): '227'
# ➡️ País: Suriname, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Tailândia, Quantidade (bruto): '16', Valor (bruto): '287'
# ➡️ País: Taiwan (Formosa), Quantidade (bruto): '995', Valor (bruto): '4.212'
# ➡️ País: Tcheca, República, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Togo, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Trinidade e Tobago, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Turquia, Quantidade (bruto): '18', Valor (bruto): '75'
# ➡️ País: Uruguai, Quantidade (bruto): '1.796', Valor (bruto): '15.322'
# ➡️ País: Vanuatu, Quantidade (bruto): '14', Valor (bruto): '31'
# ➡️ País: Venezuela, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Vietnã, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Outros(1), Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Total, Quantidade (bruto): '771.066', Valor (bruto): '2.148.121'
#
# 📥 Coletando dados para opt_06 - Uvas frescas (subopt_03) - Ano 2020
# ❌ Ignorando linha com 0 colunas: []
# ➡️ País: Africa do Sul, Quantidade (bruto): '44', Valor (bruto): '152'
# ➡️ País: Alemanha, República Democrática, Quantidade (bruto): '1.371.694', Valor (bruto): '2.791.556'
# ➡️ País: Angola, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Antígua e Barbuda, Quantidade (bruto): '304', Valor (bruto): '1.013'
# ➡️ País: Arabia Saudita, Quantidade (bruto): '32.325', Valor (bruto): '95.999'
# ➡️ País: Argélia, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Argentina, Quantidade (bruto): '2.002.784', Valor (bruto): '3.707.550'
# ➡️ País: Áustria, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Bahamas, Quantidade (bruto): '3.208', Valor (bruto): '9.449'
# ➡️ País: Bahrein, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Bangladesh, Quantidade (bruto): '30', Valor (bruto): '214'
# ➡️ País: Barbados, Quantidade (bruto): '83', Valor (bruto): '197'
# ➡️ País: Barein, Quantidade (bruto): '250', Valor (bruto): '796'
# ➡️ País: Bélgica, Quantidade (bruto): '12.757', Valor (bruto): '24.336'
# ➡️ País: Belize, Quantidade (bruto): '20', Valor (bruto): '32'
# ➡️ País: Bermudas, Quantidade (bruto): '390', Valor (bruto): '1.375'
# ➡️ País: Bolívia, Quantidade (bruto): '92.974', Valor (bruto): '34.914'
# ➡️ País: Bósnia, Quantidade (bruto): '447', Valor (bruto): '472'
# ➡️ País: Brasil, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Bulgária, Quantidade (bruto): '100', Valor (bruto): '170'
# ➡️ País: Burquina Faso, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Cabo Verde, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Camarões, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Camores, Quantidade (bruto): '10', Valor (bruto): '34'
# ➡️ País: Canadá, Quantidade (bruto): '86.635', Valor (bruto): '457.420'
# ➡️ País: Catar, Quantidade (bruto): '336', Valor (bruto): '432'
# ➡️ País: Cayman, Ilhas, Quantidade (bruto): '341', Valor (bruto): '1.130'
# ➡️ País: Chile, Quantidade (bruto): '266', Valor (bruto): '826'
# ➡️ País: China, Quantidade (bruto): '1.197', Valor (bruto): '3.370'
# ➡️ País: Chipre, Quantidade (bruto): '3.407', Valor (bruto): '8.717'
# ➡️ País: Cingapura, Quantidade (bruto): '6.933', Valor (bruto): '29.402'
# ➡️ País: Cocos (Keeling), Ilhas, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Cook, Ilhas, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Colômbia, Quantidade (bruto): '15', Valor (bruto): '45'
# ➡️ País: Congo, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Coreia do Norte, Quantidade (bruto): '30', Valor (bruto): '119'
# ➡️ País: Coreia do Sul, Quantidade (bruto): '226', Valor (bruto): '517'
# ➡️ País: Costa do Marfim, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Coveite, Quantidade (bruto): '1.572', Valor (bruto): '3.000'
# ➡️ País: Croácia, Quantidade (bruto): '16', Valor (bruto): '104'
# ➡️ País: Curaçao, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Dinamarca, Quantidade (bruto): '62.450', Valor (bruto): '135.756'
# ➡️ País: Djibuti, Quantidade (bruto): '25', Valor (bruto): '41'
# ➡️ País: Egito, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Emirados Árabes Unidos, Quantidade (bruto): '220.576', Valor (bruto): '630.862'
# ➡️ País: Eslovênia, Quantidade (bruto): '10', Valor (bruto): '29'
# ➡️ País: Espanha, Quantidade (bruto): '1.743.131', Valor (bruto): '3.842.045'
# ➡️ País: Estados Unidos, Quantidade (bruto): '7.879.841', Valor (bruto): '22.376.155'
# ➡️ País: Falkland (Ilhas Malvinas), Quantidade (bruto): '15', Valor (bruto): '100'
# ➡️ País: Faroé, Ilhas, Quantidade (bruto): '25', Valor (bruto): '98'
# ➡️ País: Filipinas, Quantidade (bruto): '441', Valor (bruto): '1.135'
# ➡️ País: Finlândia, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: França, Quantidade (bruto): '1.419', Valor (bruto): '11.552'
# ➡️ País: Gabão, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Gana, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Georgia, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Gibraltar, Quantidade (bruto): '243', Valor (bruto): '709'
# ➡️ País: Grécia, Quantidade (bruto): '2.802', Valor (bruto): '6.767'
# ➡️ País: Guadalupe, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Guiana, Quantidade (bruto): '1.432', Valor (bruto): '3.754'
# ➡️ País: Guiana Francesa, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Guiné-Bissau, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Guine Equatorial, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Honduras, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Hong Kong, Quantidade (bruto): '19.362', Valor (bruto): '198.977'
# ➡️ País: Ilha de Man, Quantidade (bruto): '136', Valor (bruto): '411'
# ➡️ País: Ilhas Virgens, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Índia, Quantidade (bruto): '502', Valor (bruto): '1.167'
# ➡️ País: Indonésia, Quantidade (bruto): '13', Valor (bruto): '40'
# ➡️ País: Irã, Quantidade (bruto): '218', Valor (bruto): '531'
# ➡️ País: Iraque, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Irlanda, Quantidade (bruto): '805.090', Valor (bruto): '1.768.519'
# ➡️ País: Islândia, Quantidade (bruto): '40', Valor (bruto): '61'
# ➡️ País: Itália, Quantidade (bruto): '118', Valor (bruto): '301'
# ➡️ País: Japão, Quantidade (bruto): '779', Valor (bruto): '2.157'
# ➡️ País: Jérsei, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Jordânia, Quantidade (bruto): '31', Valor (bruto): '75'
# ➡️ País: Letônia, Quantidade (bruto): '40', Valor (bruto): '102'
# ➡️ País: Líbano, Quantidade (bruto): '33', Valor (bruto): '119'
# ➡️ País: Libéria, Quantidade (bruto): '10.238', Valor (bruto): '30.285'
# ➡️ País: Líbia, Quantidade (bruto): '20', Valor (bruto): '55'
# ➡️ País: Lituânia, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Luxemburgo, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Macedônia, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Malásia, Quantidade (bruto): '2.065', Valor (bruto): '30.729'
# ➡️ País: Malta, Quantidade (bruto): '4.282', Valor (bruto): '11.606'
# ➡️ País: Marianas do Norte, Ilhas, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Marrocos, Quantidade (bruto): '8', Valor (bruto): '22'
# ➡️ País: Marshall, Ilhas, Quantidade (bruto): '13.769', Valor (bruto): '41.407'
# ➡️ País: Martinica, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Mauricio, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Mauritânia, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Mexico, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Mônaco, Quantidade (bruto): '20', Valor (bruto): '59'
# ➡️ País: Mongólia, Quantidade (bruto): '10', Valor (bruto): '15'
# ➡️ País: Montenegro, Quantidade (bruto): '40', Valor (bruto): '147'
# ➡️ País: Nigéria, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Noruega, Quantidade (bruto): '183.232', Valor (bruto): '572.588'
# ➡️ País: Omã, Quantidade (bruto): '43', Valor (bruto): '234'
# ➡️ País: Países Baixos, Quantidade (bruto): '20.360.309', Valor (bruto): '40.052.845'
# ➡️ País: Palau, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Panamá, Quantidade (bruto): '10.170', Valor (bruto): '25.834'
# ➡️ País: Paquistão, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Paraguai, Quantidade (bruto): '3.750', Valor (bruto): '2.881'
# ➡️ País: Pitcairn, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Polônia, Quantidade (bruto): '4', Valor (bruto): '7'
# ➡️ País: Porto Rico, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Portugal, Quantidade (bruto): '15.803', Valor (bruto): '26.426'
# ➡️ País: Quirguistão, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Reino Unido, Quantidade (bruto): '13.978.476', Valor (bruto): '31.486.021'
# ➡️ País: Republica Dominicana, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Romênia, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Rússia,  Federação da, Quantidade (bruto): '216.906', Valor (bruto): '472.154'
# ➡️ País: Samoa Americana, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: São Cristóvão e Névis, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: São Tomé e Príncipe, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: São Vicente e Granadinas, Quantidade (bruto): '20', Valor (bruto): '69'
# ➡️ País: Serra Leoa, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Senegal, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Singapura, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Sri Lanka, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Suazilândia, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Suécia, Quantidade (bruto): '50', Valor (bruto): '163'
# ➡️ País: Suíça, Quantidade (bruto): '2.209', Valor (bruto): '20.998'
# ➡️ País: Suriname, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Tailândia, Quantidade (bruto): '762', Valor (bruto): '3.001'
# ➡️ País: Taiwan, Quantidade (bruto): '90', Valor (bruto): '242'
# ➡️ País: Tanzânia, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Togo, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Trindade e Tobago, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Tunísia, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Turcas e Caicos, ilhas, Quantidade (bruto): '18', Valor (bruto): '51'
# ➡️ País: Turquia, Quantidade (bruto): '353', Valor (bruto): '868'
# ➡️ País: Tuvalu, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Uruguai, Quantidade (bruto): '68.196', Valor (bruto): '58.419'
# ➡️ País: Vanuatu, Quantidade (bruto): '26', Valor (bruto): '73'
# ➡️ País: Venezuela, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Vietnã, Quantidade (bruto): '18', Valor (bruto): '49'
# ➡️ País: Wallis e Futuna, Ilhas, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Provisão de Navios e Aeronaves, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Total, Quantidade (bruto): '49.228.053', Valor (bruto): '108.992.052'
#
# 📥 Coletando dados para opt_06 - Suco de uva (subopt_04) - Ano 2020
# ❌ Ignorando linha com 0 colunas: []
# ➡️ País: África do Sul, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Alemanha, República Democrática da, Quantidade (bruto): '86', Valor (bruto): '44'
# ➡️ País: Angola, Quantidade (bruto): '17.766', Valor (bruto): '21.627'
# ➡️ País: Antígua e Barbuda, Quantidade (bruto): '36', Valor (bruto): '25'
# ➡️ País: Antilhas Holandesas, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Arábia Saudita, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Argélia, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Argentina, Quantidade (bruto): '5.140', Valor (bruto): '8.209'
# ➡️ País: Aruba, Quantidade (bruto): '450', Valor (bruto): '788'
# ➡️ País: Austrália, Quantidade (bruto): '1.638', Valor (bruto): '3.939'
# ➡️ País: Áustria, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Bahamas, Quantidade (bruto): '34', Valor (bruto): '41'
# ➡️ País: Bangladesh, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Barbados, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Barein, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Bélgica, Quantidade (bruto): '117', Valor (bruto): '196'
# ➡️ País: Belize, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Benin, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Bermudas, Quantidade (bruto): '24', Valor (bruto): '27'
# ➡️ País: Birmânia, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Bolívia, Quantidade (bruto): '21.435', Valor (bruto): '26.745'
# ➡️ País: Brasil, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Bulgária, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Cabo Verde, Quantidade (bruto): '270', Valor (bruto): '224'
# ➡️ País: Camarões, Quantidade (bruto): '20', Valor (bruto): '29'
# ➡️ País: Canadá, Quantidade (bruto): '14.943', Valor (bruto): '19.320'
# ➡️ País: Catar, Quantidade (bruto): '5', Valor (bruto): '47'
# ➡️ País: Cayman, Ilhas, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Chile, Quantidade (bruto): '5.320', Valor (bruto): '6.612'
# ➡️ País: China, Quantidade (bruto): '240.845', Valor (bruto): '413.169'
# ➡️ País: Chipre, Quantidade (bruto): '252', Valor (bruto): '315'
# ➡️ País: Cingapura, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Colômbia, Quantidade (bruto): '1', Valor (bruto): '2'
# ➡️ País: Congo, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Coreia do Sul, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Costa do Marfim, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Costa Rica, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Coveite, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Cuba, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Curaçao, Quantidade (bruto): '1.727', Valor (bruto): '2.012'
# ➡️ País: Dinamarca, Quantidade (bruto): '90', Valor (bruto): '143'
# ➡️ País: Dominica, Ilha de, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: El Salvador, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Emirados Árabes Unidos, Quantidade (bruto): '396', Valor (bruto): '455'
# ➡️ País: Equador, Quantidade (bruto): '14.268', Valor (bruto): '21.675'
# ➡️ País: Espanha, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Estados Unidos, Quantidade (bruto): '73.431', Valor (bruto): '122.865'
# ➡️ País: Falkland (Malvinas), Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Filipinas, Quantidade (bruto): '109', Valor (bruto): '95'
# ➡️ País: Finlândia, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: França, Quantidade (bruto): '12', Valor (bruto): '38'
# ➡️ País: Gabão, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Gana, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Gibraltar, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Granada, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Grécia, Quantidade (bruto): '392', Valor (bruto): '371'
# ➡️ País: Guatemala, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Guiana, Quantidade (bruto): '350', Valor (bruto): '1.078'
# ➡️ País: Guiana Francesa, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Guiné Bissau, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Guine Equatorial, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Haiti, Quantidade (bruto): '420', Valor (bruto): '438'
# ➡️ País: Hong Kong, Quantidade (bruto): '1.170', Valor (bruto): '1.126'
# ➡️ País: Hungria, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Ilha de Man, Quantidade (bruto): '24', Valor (bruto): '22'
# ➡️ País: India, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Indonésia, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Irã, Quantidade (bruto): '150', Valor (bruto): '206'
# ➡️ País: Iraque, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Irlanda, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Israel, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Itália, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Iugoslâvia, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Jamaica, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Japão, Quantidade (bruto): '481.953', Valor (bruto): '1.128.364'
# ➡️ País: Líbano, Quantidade (bruto): '9', Valor (bruto): '4'
# ➡️ País: Libéria, Quantidade (bruto): '842', Valor (bruto): '1.194'
# ➡️ País: Líbia, Quantidade (bruto): '16.587', Valor (bruto): '22.232'
# ➡️ País: Luxemburgo, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Malásia, Quantidade (bruto): '10.070', Valor (bruto): '22.066'
# ➡️ País: Malta, Quantidade (bruto): '2.364', Valor (bruto): '2.825'
# ➡️ País: Marshall, Ilhas, Quantidade (bruto): '1.479', Valor (bruto): '1.844'
# ➡️ País: Mauritânia, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: México, Quantidade (bruto): '46.857', Valor (bruto): '112.458'
# ➡️ País: Moçambique, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Mônaco, Quantidade (bruto): '36', Valor (bruto): '37'
# ➡️ País: Montenegro, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Namíbia, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Nigéria, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Noruega, Quantidade (bruto): '554', Valor (bruto): '580'
# ➡️ País: Nova Caledônia, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Nova Zelândia, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Países Baixos, Quantidade (bruto): '84', Valor (bruto): '109'
# ➡️ País: Panamá, Quantidade (bruto): '1.335', Valor (bruto): '1.714'
# ➡️ País: Paquistão, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Paraguai, Quantidade (bruto): '216.654', Valor (bruto): '228.263'
# ➡️ País: Peru, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Polônia, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Porto Rico, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Portugal, Quantidade (bruto): '105.284', Valor (bruto): '96.479'
# ➡️ País: Quênia, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Reino Unido, Quantidade (bruto): '1.464', Valor (bruto): '2.373'
# ➡️ País: República Centro Africana, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: República Dominicana, Quantidade (bruto): '14.840', Valor (bruto): '56.540'
# ➡️ País: República Federativa da Rússia, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Rússia, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: São Tomé e Príncipe, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Senegal, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Serra Leoa, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Singapura, Quantidade (bruto): '3.526', Valor (bruto): '12.989'
# ➡️ País: Sri Lanka, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Suécia, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Suíça, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Suriname, Quantidade (bruto): '13.030', Valor (bruto): '31.236'
# ➡️ País: Tailândia, Quantidade (bruto): '1.278', Valor (bruto): '5.183'
# ➡️ País: Taiwan (Formosa), Quantidade (bruto): '58.358', Valor (bruto): '107.799'
# ➡️ País: Tanzânia, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Tcheca, República, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Togo, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Toquelau, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Trinidade e Tobago, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Turquia, Quantidade (bruto): '48', Valor (bruto): '54'
# ➡️ País: Uruguai, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Vanuatu, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Venezuela, Quantidade (bruto): '240', Valor (bruto): '230'
# ➡️ País: Total, Quantidade (bruto): '1.377.813', Valor (bruto): '2.486.456'
#
# 📥 Coletando dados para opt_06 - Vinhos de mesa (subopt_01) - Ano 2021
# ❌ Ignorando linha com 0 colunas: []
# ➡️ País: Afeganistão, Quantidade (bruto): '11', Valor (bruto): '46'
# ➡️ País: África do Sul, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Alemanha, República Democrática, Quantidade (bruto): '2.698', Valor (bruto): '6.741'
# ➡️ País: Angola, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Anguilla, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Antígua e Barbuda, Quantidade (bruto): '805', Valor (bruto): '2.268'
# ➡️ País: Antilhas Holandesas, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Arábia Saudita, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Argélia, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Argentina, Quantidade (bruto): '6', Valor (bruto): '13'
# ➡️ País: Aruba, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Austrália, Quantidade (bruto): '705', Valor (bruto): '4.034'
# ➡️ País: Áustria, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Bahamas, Quantidade (bruto): '1.083', Valor (bruto): '4.567'
# ➡️ País: Bangladesh, Quantidade (bruto): '2', Valor (bruto): '20'
# ➡️ País: Barbados, Quantidade (bruto): '216', Valor (bruto): '844'
# ➡️ País: Barein, Quantidade (bruto): '302', Valor (bruto): '894'
# ➡️ País: Bélgica, Quantidade (bruto): '483', Valor (bruto): '3.749'
# ➡️ País: Belice, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Benin, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Bermudas, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Bolívia, Quantidade (bruto): '5.850', Valor (bruto): '8.360'
# ➡️ País: Bósnia-Herzegovina, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Brasil, Quantidade (bruto): '31', Valor (bruto): '46'
# ➡️ País: Bulgária, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Cabo Verde, Quantidade (bruto): '16', Valor (bruto): '124'
# ➡️ País: Camarões, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Canadá, Quantidade (bruto): '1.172', Valor (bruto): '6.157'
# ➡️ País: Catar, Quantidade (bruto): '1', Valor (bruto): '2'
# ➡️ País: Cayman, Ilhas, Quantidade (bruto): '104', Valor (bruto): '356'
# ➡️ País: Chile, Quantidade (bruto): '26', Valor (bruto): '6'
# ➡️ País: China, Quantidade (bruto): '61.884', Valor (bruto): '264.116'
# ➡️ País: Chipre, Quantidade (bruto): '1.855', Valor (bruto): '4.530'
# ➡️ País: Cingapura, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Cocos (Keeling), Ilhas, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Colômbia, Quantidade (bruto): '12.160', Valor (bruto): '21.867'
# ➡️ País: Comores, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Congo, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Coreia, Republica Sul, Quantidade (bruto): '67', Valor (bruto): '100'
# ➡️ País: Costa do Marfim, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Costa Rica, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Coveite (Kuweit), Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Croácia, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Cuba, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Curaçao, Quantidade (bruto): '32.263', Valor (bruto): '58.993'
# ➡️ País: Dinamarca, Quantidade (bruto): '87', Valor (bruto): '504'
# ➡️ País: Dominica, Quantidade (bruto): '460', Valor (bruto): '634'
# ➡️ País: El Salvador, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Emirados Arabes Unidos, Quantidade (bruto): '810', Valor (bruto): '10.522'
# ➡️ País: Equador, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Eslovaca, Republica, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Espanha, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Estados Unidos, Quantidade (bruto): '111.085', Valor (bruto): '203.554'
# ➡️ País: Estônia, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Filipinas, Quantidade (bruto): '2.784', Valor (bruto): '10.368'
# ➡️ País: Finlândia, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: França, Quantidade (bruto): '7.052', Valor (bruto): '23.742'
# ➡️ País: Gabão, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Gana, Quantidade (bruto): '12.578', Valor (bruto): '19.196'
# ➡️ País: Gibraltar, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Granada, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Grécia, Quantidade (bruto): '908', Valor (bruto): '3.014'
# ➡️ País: Guatemala, Quantidade (bruto): '17.347', Valor (bruto): '29.100'
# ➡️ País: Guiana, Quantidade (bruto): '2.372', Valor (bruto): '6.525'
# ➡️ País: Guiana Francesa, Quantidade (bruto): '90', Valor (bruto): '32'
# ➡️ País: Guine Bissau, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Guine Equatorial, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Haiti, Quantidade (bruto): '670.379', Valor (bruto): '831.181'
# ➡️ País: Honduras, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Hong Kong, Quantidade (bruto): '12.507', Valor (bruto): '39.390'
# ➡️ País: Hungria, Quantidade (bruto): '87', Valor (bruto): '583'
# ➡️ País: Ilha de Man, Quantidade (bruto): '97', Valor (bruto): '445'
# ➡️ País: Ilhas Virgens, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Índia, Quantidade (bruto): '13', Valor (bruto): '86'
# ➡️ País: Indonésia, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Irã, Quantidade (bruto): '116', Valor (bruto): '287'
# ➡️ País: Iraque, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Irlanda, Quantidade (bruto): '36', Valor (bruto): '208'
# ➡️ País: Itália, Quantidade (bruto): '696', Valor (bruto): '3.715'
# ➡️ País: Jamaica, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Japão, Quantidade (bruto): '39.491', Valor (bruto): '90.275'
# ➡️ País: Jordânia, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Letônia, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Líbano, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Libéria, Quantidade (bruto): '7.554', Valor (bruto): '23.060'
# ➡️ País: Luxemburgo, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Macau, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Malásia, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Malavi, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Malta, Quantidade (bruto): '3.441', Valor (bruto): '15.454'
# ➡️ País: Marshall, Ilhas, Quantidade (bruto): '8.644', Valor (bruto): '22.561'
# ➡️ País: Martinica, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Mauritânia, Quantidade (bruto): '9', Valor (bruto): '85'
# ➡️ País: México, Quantidade (bruto): '9', Valor (bruto): '2'
# ➡️ País: Moçambique, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Montenegro, Quantidade (bruto): '14', Valor (bruto): '65'
# ➡️ País: Namíbia, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Nicarágua, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Nigéria, Quantidade (bruto): '68.247', Valor (bruto): '113.172'
# ➡️ País: Noruega, Quantidade (bruto): '1.878', Valor (bruto): '8.320'
# ➡️ País: Nova Caledônia, Quantidade (bruto): '7.227', Valor (bruto): '11.924'
# ➡️ País: Nova Zelândia, Quantidade (bruto): '657', Valor (bruto): '10.477'
# ➡️ País: Omã, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Países Baixos, Quantidade (bruto): '3.791', Valor (bruto): '8.484'
# ➡️ País: Palau, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Panamá, Quantidade (bruto): '29.520', Valor (bruto): '48.444'
# ➡️ País: Paraguai, Quantidade (bruto): '6.522.527', Valor (bruto): '7.192.362'
# ➡️ País: Peru, Quantidade (bruto): '9.720', Valor (bruto): '17.107'
# ➡️ País: Pitcairn, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Polônia, Quantidade (bruto): '4', Valor (bruto): '14'
# ➡️ País: Porto Rico, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Portugal, Quantidade (bruto): '6.358', Valor (bruto): '42.633'
# ➡️ País: Quênia, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Reino Unido, Quantidade (bruto): '25.316', Valor (bruto): '122.394'
# ➡️ País: República Dominicana, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Rússia, Quantidade (bruto): '181.931', Valor (bruto): '312.926'
# ➡️ País: São Cristóvão e Névis, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: São Tomé e Príncipe, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: São Vicente e Granadinas, Quantidade (bruto): '8', Valor (bruto): '48'
# ➡️ País: Senegal, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Serra Leoa, Quantidade (bruto): '6.525', Valor (bruto): '12.955'
# ➡️ País: Sérvia, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Singapura, Quantidade (bruto): '4.504', Valor (bruto): '14.346'
# ➡️ País: Suazilândia, Quantidade (bruto): '10', Valor (bruto): '24'
# ➡️ País: Suécia, Quantidade (bruto): '23', Valor (bruto): '74'
# ➡️ País: Suíça, Quantidade (bruto): '627', Valor (bruto): '6.999'
# ➡️ País: Suriname, Quantidade (bruto): '900', Valor (bruto): '1.472'
# ➡️ País: Tailândia, Quantidade (bruto): '1.334', Valor (bruto): '2.529'
# ➡️ País: Taiwan (Formosa), Quantidade (bruto): '1.313', Valor (bruto): '8.153'
# ➡️ País: Tanzânia, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Tcheca, República, Quantidade (bruto): '456', Valor (bruto): '5.988'
# ➡️ País: Togo, Quantidade (bruto): '1.890', Valor (bruto): '2.012'
# ➡️ País: Toquelau, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Trinidade Tobago, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Tunísia, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Turquia, Quantidade (bruto): '343', Valor (bruto): '878'
# ➡️ País: Tuvalu, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Uruguai, Quantidade (bruto): '136.774', Valor (bruto): '149.842'
# ➡️ País: Vanuatu, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Venezuela, Quantidade (bruto): '26.415', Valor (bruto): '35.944'
# ➡️ País: Vietnã, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Total, Quantidade (bruto): '8.058.704', Valor (bruto): '9.851.942'
#
# 📥 Coletando dados para opt_06 - Espumantes (subopt_02) - Ano 2021
# ❌ Ignorando linha com 0 colunas: []
# ➡️ País: África do Sul, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Alemanha, Quantidade (bruto): '142', Valor (bruto): '265'
# ➡️ País: Angola, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Antigua e Barbuda, Quantidade (bruto): '10', Valor (bruto): '82'
# ➡️ País: Antilhas Holandesas, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Argentina, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Aruba, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Australia, Quantidade (bruto): '184', Valor (bruto): '654'
# ➡️ País: Bahamas, Quantidade (bruto): '179', Valor (bruto): '461'
# ➡️ País: Bangladesh, Quantidade (bruto): '1', Valor (bruto): '28'
# ➡️ País: Barbados, Quantidade (bruto): '4', Valor (bruto): '58'
# ➡️ País: Belgica, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Benin, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Bermudas, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Bolívia, Quantidade (bruto): '21.235', Valor (bruto): '64.988'
# ➡️ País: Bósnia-Herzegovina, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Bulgaria, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Cabo Verde, Quantidade (bruto): '2', Valor (bruto): '12'
# ➡️ País: Camarões, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Canada, Quantidade (bruto): '253', Valor (bruto): '566'
# ➡️ País: Catar, Quantidade (bruto): '5', Valor (bruto): '964'
# ➡️ País: Cayman, Ilhas, Quantidade (bruto): '1', Valor (bruto): '5'
# ➡️ País: Chile, Quantidade (bruto): '72', Valor (bruto): '361'
# ➡️ País: China, Quantidade (bruto): '13.692', Valor (bruto): '49.572'
# ➡️ País: Chipre, Quantidade (bruto): '122', Valor (bruto): '350'
# ➡️ País: Cingapura, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Colombia, Quantidade (bruto): '10.280', Valor (bruto): '37.207'
# ➡️ País: Coreia do Sul, Republica da, Quantidade (bruto): '82', Valor (bruto): '200'
# ➡️ País: Costa Rica, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Cuba, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Curaçao, Quantidade (bruto): '5.525', Valor (bruto): '21.633'
# ➡️ País: Dinamarca, Quantidade (bruto): '7', Valor (bruto): '32'
# ➡️ País: Djibuti, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Dominica, Quantidade (bruto): '204', Valor (bruto): '505'
# ➡️ País: El Salvador, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Emirados Arabes Unidos, Quantidade (bruto): '90', Valor (bruto): '3.240'
# ➡️ País: Equador, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Espanha, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Estados Unidos, Quantidade (bruto): '801.082', Valor (bruto): '2.123.710'
# ➡️ País: Estonia, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Falkland (Malvinas), Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Filipinas, Quantidade (bruto): '-', Valor (bruto): '-'
# ...
# ➡️ País: Colômbia, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Congo, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Coreia do Norte, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Coreia do Sul, Quantidade (bruto): '366', Valor (bruto): '1.376'
# ➡️ País: Costa do Marfim, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Coveite, Quantidade (bruto): '3.725', Valor (bruto): '22.339'
# ➡️ País: Croácia, Quantidade (bruto): '5', Valor (bruto): '12'
# ➡️ País: Curaçao, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Dinamarca, Quantidade (bruto): '115.901', Valor (bruto): '264.623'
# ➡️ País: Djibuti, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Egito, Quantidade (bruto): '50', Valor (bruto): '153'
# ➡️ País: Emirados Árabes Unidos, Quantidade (bruto): '177.198', Valor (bruto): '672.359'
# ➡️ País: Eslovênia, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Espanha, Quantidade (bruto): '4.177.500', Valor (bruto): '7.656.023'
# ➡️ País: Estados Unidos, Quantidade (bruto): '19.529.155', Valor (bruto): '58.146.305'
# ➡️ País: Falkland (Ilhas Malvinas), Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Faroé, Ilhas, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Filipinas, Quantidade (bruto): '171', Valor (bruto): '530'
# ➡️ País: Finlândia, Quantidade (bruto): '1', Valor (bruto): '21'
# ➡️ País: França, Quantidade (bruto): '428', Valor (bruto): '2.040'
# ➡️ País: Gabão, Quantidade (bruto): '83', Valor (bruto): '316'
# ➡️ País: Gana, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Georgia, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Gibraltar, Quantidade (bruto): '114', Valor (bruto): '472'
# ➡️ País: Grécia, Quantidade (bruto): '3.036', Valor (bruto): '9.131'
# ➡️ País: Guadalupe, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Guiana, Quantidade (bruto): '4.999', Valor (bruto): '17.249'
# ➡️ País: Guiana Francesa, Quantidade (bruto): '705', Valor (bruto): '3.500'
# ➡️ País: Guiné-Bissau, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Guine Equatorial, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Honduras, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Hong Kong, Quantidade (bruto): '27.717', Valor (bruto): '136.684'
# ➡️ País: Ilha de Man, Quantidade (bruto): '311', Valor (bruto): '1.282'
# ➡️ País: Ilhas Virgens, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Índia, Quantidade (bruto): '510', Valor (bruto): '1.781'
# ➡️ País: Indonésia, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Irã, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Iraque, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Irlanda, Quantidade (bruto): '629.421', Valor (bruto): '1.732.292'
# ➡️ País: Islândia, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Itália, Quantidade (bruto): '29.040', Valor (bruto): '96.548'
# ➡️ País: Japão, Quantidade (bruto): '393', Valor (bruto): '1.413'
# ➡️ País: Jérsei, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Jordânia, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Letônia, Quantidade (bruto): '44', Valor (bruto): '92'
# ➡️ País: Líbano, Quantidade (bruto): '147', Valor (bruto): '514'
# ➡️ País: Libéria, Quantidade (bruto): '13.876', Valor (bruto): '55.239'
# ➡️ País: Líbia, Quantidade (bruto): '5', Valor (bruto): '32'
# ➡️ País: Lituânia, Quantidade (bruto): '46.041', Valor (bruto): '117.335'
# ➡️ País: Luxemburgo, Quantidade (bruto): '24', Valor (bruto): '123'
# ➡️ País: Macedônia, Quantidade (bruto): '10', Valor (bruto): '42'
# ➡️ País: Malásia, Quantidade (bruto): '74', Valor (bruto): '335'
# ➡️ País: Malta, Quantidade (bruto): '5.282', Valor (bruto): '21.528'
# ➡️ País: Marianas do Norte, Ilhas, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Marrocos, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Marshall, Ilhas, Quantidade (bruto): '14.858', Valor (bruto): '59.743'
# ➡️ País: Martinica, Quantidade (bruto): '5', Valor (bruto): '37'
# ➡️ País: Mauricio, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Mauritânia, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Mexico, Quantidade (bruto): '30', Valor (bruto): '78'
# ➡️ País: Mônaco, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Mongólia, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Montenegro, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Nigéria, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Noruega, Quantidade (bruto): '464.880', Valor (bruto): '1.524.584'
# ➡️ País: Omã, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Países Baixos, Quantidade (bruto): '26.855.736', Valor (bruto): '62.427.840'
# ➡️ País: Palau, Quantidade (bruto): '115', Valor (bruto): '307'
# ➡️ País: Panamá, Quantidade (bruto): '15.613', Valor (bruto): '58.337'
# ➡️ País: Paquistão, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Paraguai, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Pitcairn, Quantidade (bruto): '17', Valor (bruto): '68'
# ➡️ País: Polônia, Quantidade (bruto): '66', Valor (bruto): '124'
# ➡️ País: Porto Rico, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Portugal, Quantidade (bruto): '14.824', Valor (bruto): '45.165'
# ➡️ País: Quirguistão, Quantidade (bruto): '20', Valor (bruto): '121'
# ➡️ País: Reino Unido, Quantidade (bruto): '15.358.148', Valor (bruto): '37.383.249'
# ➡️ País: Republica Dominicana, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Romênia, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Rússia,  Federação da, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Samoa Americana, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: São Cristóvão e Névis, Quantidade (bruto): '36', Valor (bruto): '152'
# ➡️ País: São Tomé e Príncipe, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: São Vicente e Granadinas, Quantidade (bruto): '20', Valor (bruto): '83'
# ➡️ País: Serra Leoa, Quantidade (bruto): '2', Valor (bruto): '5'
# ➡️ País: Senegal, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Singapura, Quantidade (bruto): '15.407', Valor (bruto): '100.508'
# ➡️ País: Sri Lanka, Quantidade (bruto): '20', Valor (bruto): '30'
# ➡️ País: Suazilândia, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Suécia, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Suíça, Quantidade (bruto): '3.632', Valor (bruto): '53.106'
# ➡️ País: Suriname, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Tailândia, Quantidade (bruto): '794', Valor (bruto): '3.413'
# ➡️ País: Taiwan, Quantidade (bruto): '83', Valor (bruto): '293'
# ➡️ País: Tanzânia, Quantidade (bruto): '19', Valor (bruto): '76'
# ➡️ País: Togo, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Trindade e Tobago, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Tunísia, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Turcas e Caicos, ilhas, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Turquia, Quantidade (bruto): '334', Valor (bruto): '976'
# ➡️ País: Tuvalu, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Uruguai, Quantidade (bruto): '281.594', Valor (bruto): '547.227'
# ➡️ País: Vanuatu, Quantidade (bruto): '31', Valor (bruto): '88'
# ➡️ País: Venezuela, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Vietnã, Quantidade (bruto): '63', Valor (bruto): '177'
# ➡️ País: Wallis e Futuna, Ilhas, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Provisão de Navios e Aeronaves, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Total, Quantidade (bruto): '73.211.843', Valor (bruto): '184.388.889'
#
# 📥 Coletando dados para opt_06 - Suco de uva (subopt_04) - Ano 2023
# ❌ Ignorando linha com 0 colunas: []
# ➡️ País: África do Sul, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Alemanha, República Democrática da, Quantidade (bruto): '33', Valor (bruto): '39'
# ➡️ País: Angola, Quantidade (bruto): '55.683', Valor (bruto): '68.724'
# ➡️ País: Antígua e Barbuda, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Antilhas Holandesas, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Arábia Saudita, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Argélia, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Argentina, Quantidade (bruto): '795', Valor (bruto): '3.808'
# ➡️ País: Aruba, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Austrália, Quantidade (bruto): '9.228', Valor (bruto): '20.692'
# ➡️ País: Áustria, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Bahamas, Quantidade (bruto): '463', Valor (bruto): '674'
# ➡️ País: Bangladesh, Quantidade (bruto): '302', Valor (bruto): '352'
# ➡️ País: Barbados, Quantidade (bruto): '187', Valor (bruto): '545'
# ➡️ País: Barein, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Bélgica, Quantidade (bruto): '27', Valor (bruto): '67'
# ➡️ País: Belize, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Benin, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Bermudas, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Birmânia, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Bolívia, Quantidade (bruto): '22.246', Valor (bruto): '31.793'
# ➡️ País: Brasil, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Bulgária, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Cabo Verde, Quantidade (bruto): '90', Valor (bruto): '170'
# ➡️ País: Camarões, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Canadá, Quantidade (bruto): '29.504', Valor (bruto): '72.670'
# ➡️ País: Catar, Quantidade (bruto): '1', Valor (bruto): '8'
# ➡️ País: Cayman, Ilhas, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Chile, Quantidade (bruto): '3', Valor (bruto): '6'
# ➡️ País: China, Quantidade (bruto): '737.608', Valor (bruto): '1.525.476'
# ➡️ País: Chipre, Quantidade (bruto): '156', Valor (bruto): '40'
# ➡️ País: Cingapura, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Colômbia, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Congo, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Coreia do Sul, Quantidade (bruto): '46.146', Valor (bruto): '129.150'
# ➡️ País: Costa do Marfim, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Costa Rica, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Coveite, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Cuba, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Curaçao, Quantidade (bruto): '336', Valor (bruto): '1.122'
# ➡️ País: Dinamarca, Quantidade (bruto): '200', Valor (bruto): '299'
# ➡️ País: Dominica, Ilha de, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: El Salvador, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Emirados Árabes Unidos, Quantidade (bruto): '1.163', Valor (bruto): '1.213'
# ➡️ País: Equador, Quantidade (bruto): '21.876', Valor (bruto): '30.774'
# ➡️ País: Espanha, Quantidade (bruto): '44.592', Valor (bruto): '25.002'
# ➡️ País: Estados Unidos, Quantidade (bruto): '866.096', Valor (bruto): '2.125.880'
# ➡️ País: Falkland (Malvinas), Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Filipinas, Quantidade (bruto): '655', Valor (bruto): '748'
# ➡️ País: Finlândia, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: França, Quantidade (bruto): '192', Valor (bruto): '263'
# ➡️ País: Gabão, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Gana, Quantidade (bruto): '103.346', Valor (bruto): '175.088'
# ➡️ País: Gibraltar, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Granada, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Grécia, Quantidade (bruto): '412', Valor (bruto): '438'
# ➡️ País: Guatemala, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Guiana, Quantidade (bruto): '114', Valor (bruto): '300'
# ➡️ País: Guiana Francesa, Quantidade (bruto): '300', Valor (bruto): '90'
# ➡️ País: Guiné Bissau, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Guine Equatorial, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Haiti, Quantidade (bruto): '890', Valor (bruto): '569'
# ➡️ País: Hong Kong, Quantidade (bruto): '9.236', Valor (bruto): '14.083'
# ➡️ País: Hungria, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Ilha de Man, Quantidade (bruto): '144', Valor (bruto): '202'
# ➡️ País: India, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Indonésia, Quantidade (bruto): '2', Valor (bruto): '3'
# ➡️ País: Irã, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Iraque, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Irlanda, Quantidade (bruto): '930', Valor (bruto): '2.373'
# ➡️ País: Israel, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Itália, Quantidade (bruto): '1.655', Valor (bruto): '1.952'
# ➡️ País: Iugoslâvia, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Jamaica, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Japão, Quantidade (bruto): '2.583.100', Valor (bruto): '6.376.989'
# ➡️ País: Líbano, Quantidade (bruto): '16.800', Valor (bruto): '25.432'
# ➡️ País: Libéria, Quantidade (bruto): '1.231', Valor (bruto): '1.737'
# ➡️ País: Líbia, Quantidade (bruto): '74.988', Valor (bruto): '95.805'
# ➡️ País: Luxemburgo, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Malásia, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Malta, Quantidade (bruto): '1.575', Valor (bruto): '2.007'
# ➡️ País: Marshall, Ilhas, Quantidade (bruto): '2.936', Valor (bruto): '4.694'
# ➡️ País: Mauritânia, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: México, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Moçambique, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Mônaco, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Montenegro, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Namíbia, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Nigéria, Quantidade (bruto): '12.390', Valor (bruto): '16.966'
# ➡️ País: Noruega, Quantidade (bruto): '12', Valor (bruto): '19'
# ➡️ País: Nova Caledônia, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Nova Zelândia, Quantidade (bruto): '6.984', Valor (bruto): '17.987'
# ➡️ País: Países Baixos, Quantidade (bruto): '36', Valor (bruto): '55'
# ➡️ País: Panamá, Quantidade (bruto): '11.770', Valor (bruto): '14.148'
# ➡️ País: Paquistão, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Paraguai, Quantidade (bruto): '319.087', Valor (bruto): '366.822'
# ➡️ País: Peru, Quantidade (bruto): '34.700', Valor (bruto): '73.918'
# ➡️ País: Polônia, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Porto Rico, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Portugal, Quantidade (bruto): '79.062', Valor (bruto): '88.208'
# ➡️ País: Quênia, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Reino Unido, Quantidade (bruto): '5.290', Valor (bruto): '13.668'
# ➡️ País: República Centro Africana, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: República Dominicana, Quantidade (bruto): '25.440', Valor (bruto): '78.719'
# ➡️ País: República Federativa da Rússia, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Rússia, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: São Tomé e Príncipe, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Senegal, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Serra Leoa, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Singapura, Quantidade (bruto): '1.749', Valor (bruto): '3.686'
# ➡️ País: Sri Lanka, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Suécia, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Suíça, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Suriname, Quantidade (bruto): '8.480', Valor (bruto): '23.701'
# ➡️ País: Tailândia, Quantidade (bruto): '24', Valor (bruto): '37'
# ➡️ País: Taiwan (Formosa), Quantidade (bruto): '54.173', Valor (bruto): '132.752'
# ➡️ País: Tanzânia, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Tcheca, República, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Togo, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Toquelau, Quantidade (bruto): '24', Valor (bruto): '39'
# ➡️ País: Trinidade e Tobago, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Turquia, Quantidade (bruto): '230', Valor (bruto): '455'
# ➡️ País: Uruguai, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Vanuatu, Quantidade (bruto): '-', Valor (bruto): '-'
# ➡️ País: Venezuela, Quantidade (bruto): '30.206', Valor (bruto): '47.287'
# ➡️ País: Total, Quantidade (bruto): '5.224.898', Valor (bruto): '11.619.744'

# %%
df.head()
# Out:
#     ano            tipo                             pais  quantidade_kg  \
# 0  2020  Vinhos de mesa                      Afeganistão            NaN
# 1  2020  Vinhos de mesa                    África do Sul            4.0
# 2  2020  Vinhos de mesa  Alemanha, República Democrática         6261.0
# 3  2020  Vinhos de mesa                           Angola            NaN
# 4  2020  Vinhos de mesa                         Anguilla            NaN
#
#    valor_usd
# 0        NaN
# 1       21.0
# 2    32605.0
# 3        NaN
# 4        NaN

# %%
if __name__ == "__main__":
    main()
# Out:
# 🚀 Processando opção 1/5: opt_02
# 🔎 Texto do label encontrado: Ano: [1970-2023]
# 📅 Intervalo de anos detectado: 1970 - 2023
#
# 📥 Coletando dados para o ano 1970, opção opt_02...
#
# 📥 Coletando dados para o ano 1971, opção opt_02...
#
# 📥 Coletando dados para o ano 1972, opção opt_02...
#
# 📥 Coletando dados para o ano 1973, opção opt_02...
#
# 📥 Coletando dados para o ano 1974, opção opt_02...
#
# 📥 Coletando dados para o ano 1975, opção opt_02...
#
# 📥 Coletando dados para o ano 1976, opção opt_02...
#
# 📥 Coletando dados para o ano 1977, opção opt_02...
#
# 📥 Coletando dados para o ano 1978, opção opt_02...
#
# 📥 Coletando dados para o ano 1979, opção opt_02...
#
# 📥 Coletando dados para o ano 1980, opção opt_02...
#
# 📥 Coletando dados para o ano 1981, opção opt_02...
#
# 📥 Coletando dados para o ano 1982, opção opt_02...
#
# 📥 Coletando dados para o ano 1983, opção opt_02...
#
# 📥 Coletando dados para o ano 1984, opção opt_02...
#
# 📥 Coletando dados para o ano 1985, opção opt_02...
#
# 📥 Coletando dados para o ano 1986, opção opt_02...
#
# 📥 Coletando dados para o ano 1987, opção opt_02...
#
# 📥 Coletando dados para o ano 1988, opção opt_02...
#
# 📥 Coletando dados para o ano 1989, opção opt_02...
#
# 📥 Coletando dados para o ano 1990, opção opt_02...
#
# 📥 Coletando dados para o ano 1991, opção opt_02...
#
# 📥 Coletando dados para o ano 1992, opção opt_02...
#
# 📥 Coletando dados para o ano 1993, opção opt_02...
#
# 📥 Coletando dados para o ano 1994, opção opt_02...
#
# 📥 Coletando dados para o ano 1995, opção opt_02...
#
# 📥 Coletando dados para o ano 1996, opção opt_02...
#
# 📥 Coletando dados para o ano 1997, opção opt_02...
#
# 📥 Coletando dados para o ano 1998, opção opt_02...
#
# 📥 Coletando dados para o ano 1999, opção opt_02...
#
# 📥 Coletando dados para o ano 2000, opção opt_02...
#
# 📥 Coletando dados para o ano 2001, opção opt_02...
#
# 📥 Coletando dados para o ano 2002, opção opt_02...
#
# 📥 Coletando dados para o ano 2003, opção opt_02...
#
# 📥 Coletando dados para o ano 2004, opção opt_02...
#
# 📥 Coletando dados para o ano 2005, opção opt_02...
#
# 📥 Coletando dados para o ano 2006, opção opt_02...
#
# 📥 Coletando dados para o ano 2007, opção opt_02...
#
# 📥 Coletando dados para o ano 2008, opção opt_02...
#
# 📥 Coletando dados para o ano 2009, opção opt_02...
#
# 📥 Coletando dados para o ano 2010, opção opt_02...
#
# 📥 Coletando dados para o ano 2011, opção opt_02...
#
# 📥 Coletando dados para o ano 2012, opção opt_02...
#
# 📥 Coletando dados para o ano 2013, opção opt_02...
#
# 📥 Coletando dados para o ano 2014, opção opt_02...
#
# 📥 Coletando dados para o ano 2015, opção opt_02...
#
# 📥 Coletando dados para o ano 2016, opção opt_02...
#
# 📥 Coletando dados para o ano 2017, opção opt_02...
#
# 📥 Coletando dados para o ano 2018, opção opt_02...
#
# 📥 Coletando dados para o ano 2019, opção opt_02...
#
# 📥 Coletando dados para o ano 2020, opção opt_02...
#
# 📥 Coletando dados para o ano 2021, opção opt_02...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 2
#       1 if __name__ == "__main__":
# ----> 2     main()
#
# Cell In[9], line 16, in main()
#      13 ano_inicio, ano_fim = capturar_anos(opcao)
#      15 if ano_inicio and ano_fim:
# ---> 16     df = capturar_dados(opcao, ano_inicio, ano_fim)
#      17     if not df.empty:
#      18         dados_opcoes[opcao] = df
#
# Cell In[8], line 3, in capturar_dados(opcao, ano_inicio, ano_fim)
#       1 def capturar_dados(opcao, ano_inicio, ano_fim):
#       2     if opcao == 'opt_02':
# ----> 3         return capturar_dados_opt_02(ano_inicio, ano_fim)
#       4     elif opcao == 'opt_03':
#       5         return capturar_dados_opt_03(ano_inicio, ano_fim)
#
# Cell In[7], line 2, in capturar_dados_opt_02(ano_inicio, ano_fim)
#       1 def capturar_dados_opt_02(ano_inicio, ano_fim):
# ----> 2     return capturar_dados_opt_02_04(ano_inicio, ano_fim)
#
# Cell In[4], line 13, in capturar_dados_opt_02_04(ano_inicio, ano_fim)
#      10 url = f'http://vitibrasil.cnpuv.embrapa.br/index.php?ano={ano}&opcao=opt_02'
#      12 try:
# ---> 13     response = requests.get(url)
#      14     response.raise_for_status()
#      15     soup = BeautifulSoup(response.text, 'html.parser')
#
# File c:\Users\gusta\OneDrive\Área de Trabalho\FIAP\.venv\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)     70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File c:\Users\gusta\OneDrive\Área de Trabalho\FIAP\.venv\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\gusta\OneDrive\Área de Trabalho\FIAP\.venv\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\gusta\OneDrive\Área de Trabalho\FIAP\.venv\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Users\gusta\OneDrive\Área de Trabalho\FIAP\.venv\Lib\site-packages\requests\adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File c:\Users\gusta\OneDrive\Área de Trabalho\FIAP\.venv\Lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File c:\Users\gusta\OneDrive\Área de Trabalho\FIAP\.venv\Lib\site-packages\urllib3\connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532 # Receive the response from the server
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#     536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File c:\Users\gusta\OneDrive\Área de Trabalho\FIAP\.venv\Lib\site-packages\urllib3\connection.py:516, in HTTPConnection.getresponse(self)
#     513 _shutdown = getattr(self.sock, "shutdown", None)
#     515 # Get the response from http.client.HTTPConnection
# --> 516 httplib_response = super().getresponse()
#     518 try:
#     519     assert_header_parsing(httplib_response.msg)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.1008.0_x64__qbz5n2kfra8p0\Lib\http\client.py:1430, in HTTPConnection.getresponse(self)
#    1428 try:
#    1429     try:
# -> 1430         response.begin()
#    1431     except ConnectionError:
#    1432         self.close()
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.1008.0_x64__qbz5n2kfra8p0\Lib\http\client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.1008.0_x64__qbz5n2kfra8p0\Lib\http\client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.1008.0_x64__qbz5n2kfra8p0\Lib\socket.py:719, in SocketIO.readinto(self, b)
#     717     raise OSError("cannot read from timed out object")
#     718 try:
# --> 719     return self._sock.recv_into(b)
#     720 except timeout:
#     721     self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
df = capturar_dados_opt_05(2020, 2023)
print(df)
# Out:
# Erro ao acessar subopções de opt_05: HTTPConnectionPool(host='vitibrasil.cnpuv.embrapa.br', port=80): Max retries exceeded with url: /index.php?ano=2023&opcao=opt_05 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x0000016CE2F0B9B0>: Failed to establish a new connection: [WinError 10061] Nenhuma conexão pôde ser feita porque a máquina de destino as recusou ativamente'))
# Empty DataFrame
# Columns: []
# Index: []
